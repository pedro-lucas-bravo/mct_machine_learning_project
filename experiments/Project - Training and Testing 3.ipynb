# %%
import numpy as np
import pandas as pd
import scipy
import librosa, librosa.display
import matplotlib.pyplot as plt
import matplotlib.style as ms
#ms.use('seaborn-muted')
import IPython.display as Ipd
import os
import sklearn

# %%
def SphericalToCartesian(ele, azi, dist):
    phi = np.deg2rad(90-ele)
    theta = np.deg2rad(azi)
    
    x = dist * np.sin(phi) * np.cos(theta)
    #x=ρsinφcosθ 
    y = dist * np.sin(phi) * np.sin(theta)
    #y=ρsinφsinθ 
    z = dist * np.cos(phi)
    #z=ρcosφ
    return np.array([x, y, z])

def CartesianToSpherical(x, y, z):
    dist = np.sqrt(x*x + y*y + z*z)
    theta = np.arctan2(y,x)    
    phi = np.arccos(z/dist)
    ele = 90 - np.rad2deg(phi)
    azi = np.rad2deg(theta)
    return np.array([round(ele), round(azi), round(dist), theta])

def normalize(v):
    norm=np.linalg.norm(v)
    if norm==0:
        norm=np.finfo(v.dtype).eps
    return v/norm


#Get all metadata

filenames_meta = os.listdir('data/dcase_data/metadata_dev') #Development

full_metadata = pd.DataFrame()
#all_metadata
max_it = 400
c = 0
for i in range(len(filenames_meta)):
    metadata = pd.read_csv('data/dcase_data/metadata_dev/' + filenames_meta[i])  #Development
    coord = np.zeros((len(metadata),3))
    sphe = np.zeros((len(metadata),4))
    for index, row in metadata.iterrows():
        coord[index, :] = SphericalToCartesian(row['ele'], row['azi'], row['dist'])
        sphe[index, :] = CartesianToSpherical(coord[index, 0], coord[index, 1], coord[index, 2])
    metadata['x'] = coord[:,0]
    metadata['y'] = coord[:,1]
    metadata['z'] = coord[:,2]
    
    metadata['ele_r'] = sphe[:,0]
    metadata['azi_r'] = sphe[:,1]
    metadata['dist_r'] = sphe[:,2]
    metadata['theta'] = sphe[:,3]
    
    full_metadata = full_metadata.append(metadata, ignore_index=True, sort=False)
    c +=1
    if c == max_it:
        break
print(len(full_metadata))
print(len(full_metadata.loc[full_metadata['sound_event_recording'] == 'phone']))
# Out:
# 15798
# 1421

# %%
#defining function to interpolate 1-D dimensional arrays
def lin_interp_1d(data, out_size):
    
    in_size = data.shape[0]
    x_in = np.arange(0,in_size)
    interpolator = scipy.interpolate.interp1d(x_in, data)
    x_out = np.arange(0,in_size-1,((in_size-1)/out_size))
    output = interpolator(x_out)
    output = output[0:out_size]
    
    return output

def lin_interp_2d(data, out_size):
    
    x_in_size = data.shape[1]
    y_in_size = data.shape[0]
    x_in = np.arange(0,x_in_size)
    y_in = np.arange(0,y_in_size)
    interpolator = scipy.interpolate.interp2d(x_in, y_in, data, kind='linear')
    x_out = np.arange(0,x_in_size-1,((x_in_size-1)/out_size[1]))
    y_out = np.arange(0,y_in_size-1,((y_in_size-1)/out_size[0]))
    output = interpolator(x_out, y_out)
    output = output[0:out_size[0],0:out_size[1]]
    
    return output

# def extract_features_target(signal, location):
#     stft_amp = np.zeros((128,0))
#     stft_phase = np.zeros((128,0))
#     for i in range(4):
#         stft = librosa.stft(signal[i], n_fft=1024, hop_length=512)
#         #stft_amp = np.append(stft_amp, lin_interp_2d(librosa.amplitude_to_db(np.abs(stft)), (128,64)), axis=1)
#         stft_amp = np.append(stft_amp, lin_interp_2d(np.abs(stft), (128,64)), axis=1)
#         stft_phase = np.append(stft_phase, lin_interp_2d(np.angle(stft), (128,64)), axis = 1)

#         #print(stft_amp.shape)
#         #print(np.std(stft_amp[0]))


#     stft_amp = sklearn.preprocessing.scale(stft_amp, axis = 1)
#     stft_phase = sklearn.preprocessing.scale(stft_phase, axis = 1)

#     feature = np.append(stft_amp.flatten(), stft_phase.flatten())
#     return feature, np.array(location)



def extract_features_target(signal, location):
#     stft_w = librosa.stft(signal[0], n_fft=1024, hop_length=512)
    feature = []
#     for ch in range(1,4):
#         stft = librosa.stft(signal[ch], n_fft=1024, hop_length=512)
#         i = np.abs(np.matmul(np.conjugate(stft_w), np.transpose(stft)))
#         #i_norm = sklearn.preprocessing.normalize(lin_interp_2d(i, (64, 64)), axis = 1)
#         i_norm = librosa.util.normalize(lin_interp_2d(i, (64, 64)), axis = 1)
#         feature = np.append(feature, i_norm.flatten())
    for ch in range(1,4):    
        cross = scipy.signal.csd(signal[0], signal[ch], fs = sr, nperseg=1024, noverlap=512)
        cross = lin_interp_1d(np.abs(cross[1]), 256)
        cross = librosa.util.normalize(cross)
        feature = np.append(feature, cross)
    for ch in range(1,4):    
        cross = scipy.signal.csd(signal[0], signal[ch], fs = sr, nperseg=1024, noverlap=512)
        cross = lin_interp_1d(np.angle(cross[1]), 256)
        cross = librosa.util.normalize(cross)
        feature = np.append(feature, cross)
        
    return feature, np.array(location)

sr = 22050
filenames_meta = os.listdir('data/dcase_data/metadata_dev') #Development 65536 12288 768
features = np.zeros((len(full_metadata),1536)) #we compute the melspectrogram which once flattened will produce 22144 values
target = np.zeros((len(full_metadata),3)) #we store the 2 target values
example = 0
for i in range(max_it):
    
    #Metadata
    metadata = pd.read_csv('data/dcase_data/metadata_dev/' + filenames_meta[i])  #Development
    filename = os.path.splitext(filenames_meta[i])[0]
    
    print("processing '" + filename + "' " + str(i + 1) + "/" + str(max_it))
    
    #Audio track
    signal, dummy = librosa.load('data/dcase_data/foa_dev/' + filename + '.wav', sr, mono=False)    
    
    for s in range(len(metadata)):
        if(metadata['sound_event_recording'][s] == 'phone' ):
            #print('processing',filenames[i])
            start_time = int(metadata['start_time'][s] * sr)
            end_time = int(metadata['end_time'][s] * sr)
            #print(str(end_time - start_time))
            subsignal = librosa.util.normalize(signal[:, start_time:end_time])
            #features[example,:], target[example,:] = extract_features_target(subsignal, metadata['x'][s],  metadata['y'][s], metadata['z'][s])
            features[example,:], target[example,:] = extract_features_target(subsignal, normalize(SphericalToCartesian(metadata['ele'][s],  metadata['azi'][s], metadata['dist'][s])))
            
            #Ipd.display(Ipd.Audio(subsignal, rate=sr))
            example += 1
print(features.shape)            
features = np.delete(features, np.arange(example,features.shape[0], 1, dtype=int), axis=0)
target = np.delete(target, np.arange(example,target.shape[0], 1, dtype=int), axis=0)
print('Done!')
print(features.shape)
print(example)
# Out:
# processing 'split1_ir0_ov1_1' 1/400
# processing 'split1_ir0_ov1_10' 2/400
# processing 'split1_ir0_ov1_2' 3/400
# processing 'split1_ir0_ov1_3' 4/400
# processing 'split1_ir0_ov1_4' 5/400
# processing 'split1_ir0_ov1_5' 6/400
# processing 'split1_ir0_ov1_6' 7/400
# processing 'split1_ir0_ov1_7' 8/400
# processing 'split1_ir0_ov1_8' 9/400
# processing 'split1_ir0_ov1_9' 10/400
# processing 'split1_ir0_ov2_11' 11/400
# processing 'split1_ir0_ov2_12' 12/400
# processing 'split1_ir0_ov2_13' 13/400
# processing 'split1_ir0_ov2_14' 14/400
# processing 'split1_ir0_ov2_15' 15/400
# processing 'split1_ir0_ov2_16' 16/400
# processing 'split1_ir0_ov2_17' 17/400
# processing 'split1_ir0_ov2_18' 18/400
# processing 'split1_ir0_ov2_19' 19/400
# processing 'split1_ir0_ov2_20' 20/400
# processing 'split1_ir1_ov1_21' 21/400
# processing 'split1_ir1_ov1_22' 22/400
# processing 'split1_ir1_ov1_23' 23/400
# processing 'split1_ir1_ov1_24' 24/400
# processing 'split1_ir1_ov1_25' 25/400
# processing 'split1_ir1_ov1_26' 26/400
# processing 'split1_ir1_ov1_27' 27/400
# processing 'split1_ir1_ov1_28' 28/400
# processing 'split1_ir1_ov1_29' 29/400
# processing 'split1_ir1_ov1_30' 30/400
# processing 'split1_ir1_ov2_31' 31/400
# processing 'split1_ir1_ov2_32' 32/400
# processing 'split1_ir1_ov2_33' 33/400
# processing 'split1_ir1_ov2_34' 34/400
# processing 'split1_ir1_ov2_35' 35/400
# processing 'split1_ir1_ov2_36' 36/400
# processing 'split1_ir1_ov2_37' 37/400
# processing 'split1_ir1_ov2_38' 38/400
# processing 'split1_ir1_ov2_39' 39/400
# processing 'split1_ir1_ov2_40' 40/400
# processing 'split1_ir2_ov1_41' 41/400
# processing 'split1_ir2_ov1_42' 42/400
# processing 'split1_ir2_ov1_43' 43/400
# processing 'split1_ir2_ov1_44' 44/400
# processing 'split1_ir2_ov1_45' 45/400
# processing 'split1_ir2_ov1_46' 46/400
# processing 'split1_ir2_ov1_47' 47/400
# processing 'split1_ir2_ov1_48' 48/400
# processing 'split1_ir2_ov1_49' 49/400
# processing 'split1_ir2_ov1_50' 50/400
# processing 'split1_ir2_ov2_51' 51/400
# processing 'split1_ir2_ov2_52' 52/400
# processing 'split1_ir2_ov2_53' 53/400
# processing 'split1_ir2_ov2_54' 54/400
# processing 'split1_ir2_ov2_55' 55/400
# processing 'split1_ir2_ov2_56' 56/400
# processing 'split1_ir2_ov2_57' 57/400
# processing 'split1_ir2_ov2_58' 58/400
# processing 'split1_ir2_ov2_59' 59/400
# processing 'split1_ir2_ov2_60' 60/400
# processing 'split1_ir3_ov1_61' 61/400
# processing 'split1_ir3_ov1_62' 62/400
# processing 'split1_ir3_ov1_63' 63/400
# processing 'split1_ir3_ov1_64' 64/400
# processing 'split1_ir3_ov1_65' 65/400
# processing 'split1_ir3_ov1_66' 66/400
# processing 'split1_ir3_ov1_67' 67/400
# processing 'split1_ir3_ov1_68' 68/400
# processing 'split1_ir3_ov1_69' 69/400
# processing 'split1_ir3_ov1_70' 70/400
# processing 'split1_ir3_ov2_71' 71/400
# processing 'split1_ir3_ov2_72' 72/400
# processing 'split1_ir3_ov2_73' 73/400
# processing 'split1_ir3_ov2_74' 74/400
# processing 'split1_ir3_ov2_75' 75/400
# processing 'split1_ir3_ov2_76' 76/400
# processing 'split1_ir3_ov2_77' 77/400
# processing 'split1_ir3_ov2_78' 78/400
# processing 'split1_ir3_ov2_79' 79/400
# processing 'split1_ir3_ov2_80' 80/400
# processing 'split1_ir4_ov1_81' 81/400
# processing 'split1_ir4_ov1_82' 82/400
# processing 'split1_ir4_ov1_83' 83/400
# processing 'split1_ir4_ov1_84' 84/400
# processing 'split1_ir4_ov1_85' 85/400
# processing 'split1_ir4_ov1_86' 86/400
# processing 'split1_ir4_ov1_87' 87/400
# processing 'split1_ir4_ov1_88' 88/400
# processing 'split1_ir4_ov1_89' 89/400
# processing 'split1_ir4_ov1_90' 90/400
# processing 'split1_ir4_ov2_100' 91/400
# processing 'split1_ir4_ov2_91' 92/400
# processing 'split1_ir4_ov2_92' 93/400
# processing 'split1_ir4_ov2_93' 94/400
# processing 'split1_ir4_ov2_94' 95/400
# processing 'split1_ir4_ov2_95' 96/400
# processing 'split1_ir4_ov2_96' 97/400
# processing 'split1_ir4_ov2_97' 98/400
# processing 'split1_ir4_ov2_98' 99/400
# processing 'split1_ir4_ov2_99' 100/400
# processing 'split2_ir0_ov1_1' 101/400
# processing 'split2_ir0_ov1_10' 102/400
# processing 'split2_ir0_ov1_2' 103/400
# processing 'split2_ir0_ov1_3' 104/400
# processing 'split2_ir0_ov1_4' 105/400
# processing 'split2_ir0_ov1_5' 106/400
# processing 'split2_ir0_ov1_6' 107/400
# processing 'split2_ir0_ov1_7' 108/400
# processing 'split2_ir0_ov1_8' 109/400
# processing 'split2_ir0_ov1_9' 110/400
# processing 'split2_ir0_ov2_11' 111/400
# processing 'split2_ir0_ov2_12' 112/400
# processing 'split2_ir0_ov2_13' 113/400
# processing 'split2_ir0_ov2_14' 114/400
# processing 'split2_ir0_ov2_15' 115/400
# processing 'split2_ir0_ov2_16' 116/400
# processing 'split2_ir0_ov2_17' 117/400
# processing 'split2_ir0_ov2_18' 118/400
# processing 'split2_ir0_ov2_19' 119/400
# processing 'split2_ir0_ov2_20' 120/400
# processing 'split2_ir1_ov1_21' 121/400
# processing 'split2_ir1_ov1_22' 122/400
# processing 'split2_ir1_ov1_23' 123/400
# processing 'split2_ir1_ov1_24' 124/400
# processing 'split2_ir1_ov1_25' 125/400
# processing 'split2_ir1_ov1_26' 126/400
# processing 'split2_ir1_ov1_27' 127/400
# processing 'split2_ir1_ov1_28' 128/400
# processing 'split2_ir1_ov1_29' 129/400
# processing 'split2_ir1_ov1_30' 130/400
# processing 'split2_ir1_ov2_31' 131/400
# processing 'split2_ir1_ov2_32' 132/400
# processing 'split2_ir1_ov2_33' 133/400
# processing 'split2_ir1_ov2_34' 134/400
# processing 'split2_ir1_ov2_35' 135/400
# processing 'split2_ir1_ov2_36' 136/400
# processing 'split2_ir1_ov2_37' 137/400
# processing 'split2_ir1_ov2_38' 138/400
# processing 'split2_ir1_ov2_39' 139/400
# processing 'split2_ir1_ov2_40' 140/400
# processing 'split2_ir2_ov1_41' 141/400
# processing 'split2_ir2_ov1_42' 142/400
# processing 'split2_ir2_ov1_43' 143/400
# processing 'split2_ir2_ov1_44' 144/400
# processing 'split2_ir2_ov1_45' 145/400
# processing 'split2_ir2_ov1_46' 146/400
# processing 'split2_ir2_ov1_47' 147/400
# processing 'split2_ir2_ov1_48' 148/400
# processing 'split2_ir2_ov1_49' 149/400
# processing 'split2_ir2_ov1_50' 150/400
# processing 'split2_ir2_ov2_51' 151/400
# processing 'split2_ir2_ov2_52' 152/400
# processing 'split2_ir2_ov2_53' 153/400
# processing 'split2_ir2_ov2_54' 154/400
# processing 'split2_ir2_ov2_55' 155/400
# processing 'split2_ir2_ov2_56' 156/400
# processing 'split2_ir2_ov2_57' 157/400
# processing 'split2_ir2_ov2_58' 158/400
# processing 'split2_ir2_ov2_59' 159/400
# processing 'split2_ir2_ov2_60' 160/400
# processing 'split2_ir3_ov1_61' 161/400
# processing 'split2_ir3_ov1_62' 162/400
# processing 'split2_ir3_ov1_63' 163/400
# processing 'split2_ir3_ov1_64' 164/400
# processing 'split2_ir3_ov1_65' 165/400
# processing 'split2_ir3_ov1_66' 166/400
# processing 'split2_ir3_ov1_67' 167/400
# processing 'split2_ir3_ov1_68' 168/400
# processing 'split2_ir3_ov1_69' 169/400
# processing 'split2_ir3_ov1_70' 170/400
# processing 'split2_ir3_ov2_71' 171/400
# processing 'split2_ir3_ov2_72' 172/400
# processing 'split2_ir3_ov2_73' 173/400
# processing 'split2_ir3_ov2_74' 174/400
# processing 'split2_ir3_ov2_75' 175/400
# processing 'split2_ir3_ov2_76' 176/400
# processing 'split2_ir3_ov2_77' 177/400
# processing 'split2_ir3_ov2_78' 178/400
# processing 'split2_ir3_ov2_79' 179/400
# processing 'split2_ir3_ov2_80' 180/400
# processing 'split2_ir4_ov1_81' 181/400
# processing 'split2_ir4_ov1_82' 182/400
# processing 'split2_ir4_ov1_83' 183/400
# processing 'split2_ir4_ov1_84' 184/400
# processing 'split2_ir4_ov1_85' 185/400
# processing 'split2_ir4_ov1_86' 186/400
# processing 'split2_ir4_ov1_87' 187/400
# processing 'split2_ir4_ov1_88' 188/400
# processing 'split2_ir4_ov1_89' 189/400
# processing 'split2_ir4_ov1_90' 190/400
# processing 'split2_ir4_ov2_100' 191/400
# processing 'split2_ir4_ov2_91' 192/400
# processing 'split2_ir4_ov2_92' 193/400
# processing 'split2_ir4_ov2_93' 194/400
# processing 'split2_ir4_ov2_94' 195/400
# processing 'split2_ir4_ov2_95' 196/400
# processing 'split2_ir4_ov2_96' 197/400
# processing 'split2_ir4_ov2_97' 198/400
# processing 'split2_ir4_ov2_98' 199/400
# processing 'split2_ir4_ov2_99' 200/400
# processing 'split3_ir0_ov1_1' 201/400
# processing 'split3_ir0_ov1_10' 202/400
# processing 'split3_ir0_ov1_2' 203/400
# processing 'split3_ir0_ov1_3' 204/400
# processing 'split3_ir0_ov1_4' 205/400
# processing 'split3_ir0_ov1_5' 206/400
# processing 'split3_ir0_ov1_6' 207/400
# processing 'split3_ir0_ov1_7' 208/400
# processing 'split3_ir0_ov1_8' 209/400
# processing 'split3_ir0_ov1_9' 210/400
# processing 'split3_ir0_ov2_11' 211/400
# processing 'split3_ir0_ov2_12' 212/400
# processing 'split3_ir0_ov2_13' 213/400
# processing 'split3_ir0_ov2_14' 214/400
# processing 'split3_ir0_ov2_15' 215/400
# processing 'split3_ir0_ov2_16' 216/400
# processing 'split3_ir0_ov2_17' 217/400
# processing 'split3_ir0_ov2_18' 218/400
# processing 'split3_ir0_ov2_19' 219/400
# processing 'split3_ir0_ov2_20' 220/400
# processing 'split3_ir1_ov1_21' 221/400
# processing 'split3_ir1_ov1_22' 222/400
# processing 'split3_ir1_ov1_23' 223/400
# processing 'split3_ir1_ov1_24' 224/400
# processing 'split3_ir1_ov1_25' 225/400
# processing 'split3_ir1_ov1_26' 226/400
# processing 'split3_ir1_ov1_27' 227/400
# processing 'split3_ir1_ov1_28' 228/400
# processing 'split3_ir1_ov1_29' 229/400
# processing 'split3_ir1_ov1_30' 230/400
# processing 'split3_ir1_ov2_31' 231/400
# processing 'split3_ir1_ov2_32' 232/400
# processing 'split3_ir1_ov2_33' 233/400
# processing 'split3_ir1_ov2_34' 234/400
# processing 'split3_ir1_ov2_35' 235/400
# processing 'split3_ir1_ov2_36' 236/400
# processing 'split3_ir1_ov2_37' 237/400
# processing 'split3_ir1_ov2_38' 238/400
# processing 'split3_ir1_ov2_39' 239/400
# processing 'split3_ir1_ov2_40' 240/400
# processing 'split3_ir2_ov1_41' 241/400
# processing 'split3_ir2_ov1_42' 242/400
# processing 'split3_ir2_ov1_43' 243/400
# processing 'split3_ir2_ov1_44' 244/400
# processing 'split3_ir2_ov1_45' 245/400
# processing 'split3_ir2_ov1_46' 246/400
# processing 'split3_ir2_ov1_47' 247/400
# processing 'split3_ir2_ov1_48' 248/400
# processing 'split3_ir2_ov1_49' 249/400
# processing 'split3_ir2_ov1_50' 250/400
# processing 'split3_ir2_ov2_51' 251/400
# processing 'split3_ir2_ov2_52' 252/400
# processing 'split3_ir2_ov2_53' 253/400
# processing 'split3_ir2_ov2_54' 254/400
# processing 'split3_ir2_ov2_55' 255/400
# processing 'split3_ir2_ov2_56' 256/400
# processing 'split3_ir2_ov2_57' 257/400
# processing 'split3_ir2_ov2_58' 258/400
# processing 'split3_ir2_ov2_59' 259/400
# processing 'split3_ir2_ov2_60' 260/400
# processing 'split3_ir3_ov1_61' 261/400
# processing 'split3_ir3_ov1_62' 262/400
# processing 'split3_ir3_ov1_63' 263/400
# processing 'split3_ir3_ov1_64' 264/400
# processing 'split3_ir3_ov1_65' 265/400
# processing 'split3_ir3_ov1_66' 266/400
# processing 'split3_ir3_ov1_67' 267/400
# processing 'split3_ir3_ov1_68' 268/400
# processing 'split3_ir3_ov1_69' 269/400
# processing 'split3_ir3_ov1_70' 270/400
# processing 'split3_ir3_ov2_71' 271/400
# processing 'split3_ir3_ov2_72' 272/400
# processing 'split3_ir3_ov2_73' 273/400
# processing 'split3_ir3_ov2_74' 274/400
# processing 'split3_ir3_ov2_75' 275/400
# processing 'split3_ir3_ov2_76' 276/400
# processing 'split3_ir3_ov2_77' 277/400
# processing 'split3_ir3_ov2_78' 278/400
# processing 'split3_ir3_ov2_79' 279/400
# processing 'split3_ir3_ov2_80' 280/400
# processing 'split3_ir4_ov1_81' 281/400
# processing 'split3_ir4_ov1_82' 282/400
# processing 'split3_ir4_ov1_83' 283/400
# processing 'split3_ir4_ov1_84' 284/400
# processing 'split3_ir4_ov1_85' 285/400
# processing 'split3_ir4_ov1_86' 286/400
# processing 'split3_ir4_ov1_87' 287/400
# processing 'split3_ir4_ov1_88' 288/400
# processing 'split3_ir4_ov1_89' 289/400
# processing 'split3_ir4_ov1_90' 290/400
# processing 'split3_ir4_ov2_100' 291/400
# processing 'split3_ir4_ov2_91' 292/400
# processing 'split3_ir4_ov2_92' 293/400
# processing 'split3_ir4_ov2_93' 294/400
# processing 'split3_ir4_ov2_94' 295/400
# processing 'split3_ir4_ov2_95' 296/400
# processing 'split3_ir4_ov2_96' 297/400
# processing 'split3_ir4_ov2_97' 298/400
# processing 'split3_ir4_ov2_98' 299/400
# processing 'split3_ir4_ov2_99' 300/400
# processing 'split4_ir0_ov1_1' 301/400
# processing 'split4_ir0_ov1_10' 302/400
# processing 'split4_ir0_ov1_2' 303/400
# processing 'split4_ir0_ov1_3' 304/400
# processing 'split4_ir0_ov1_4' 305/400
# processing 'split4_ir0_ov1_5' 306/400
# processing 'split4_ir0_ov1_6' 307/400
# processing 'split4_ir0_ov1_7' 308/400
# processing 'split4_ir0_ov1_8' 309/400
# processing 'split4_ir0_ov1_9' 310/400
# processing 'split4_ir0_ov2_11' 311/400
# processing 'split4_ir0_ov2_12' 312/400
# processing 'split4_ir0_ov2_13' 313/400
# processing 'split4_ir0_ov2_14' 314/400
# processing 'split4_ir0_ov2_15' 315/400
# processing 'split4_ir0_ov2_16' 316/400
# processing 'split4_ir0_ov2_17' 317/400
# processing 'split4_ir0_ov2_18' 318/400
# processing 'split4_ir0_ov2_19' 319/400
# processing 'split4_ir0_ov2_20' 320/400
# processing 'split4_ir1_ov1_21' 321/400
# processing 'split4_ir1_ov1_22' 322/400
# processing 'split4_ir1_ov1_23' 323/400
# processing 'split4_ir1_ov1_24' 324/400
# processing 'split4_ir1_ov1_25' 325/400
# processing 'split4_ir1_ov1_26' 326/400
# processing 'split4_ir1_ov1_27' 327/400
# processing 'split4_ir1_ov1_28' 328/400
# processing 'split4_ir1_ov1_29' 329/400
# processing 'split4_ir1_ov1_30' 330/400
# processing 'split4_ir1_ov2_31' 331/400
# processing 'split4_ir1_ov2_32' 332/400
# processing 'split4_ir1_ov2_33' 333/400
# processing 'split4_ir1_ov2_34' 334/400
# processing 'split4_ir1_ov2_35' 335/400
# processing 'split4_ir1_ov2_36' 336/400
# processing 'split4_ir1_ov2_37' 337/400
# processing 'split4_ir1_ov2_38' 338/400
# processing 'split4_ir1_ov2_39' 339/400
# processing 'split4_ir1_ov2_40' 340/400
# processing 'split4_ir2_ov1_41' 341/400
# processing 'split4_ir2_ov1_42' 342/400
# processing 'split4_ir2_ov1_43' 343/400
# processing 'split4_ir2_ov1_44' 344/400
# processing 'split4_ir2_ov1_45' 345/400
# processing 'split4_ir2_ov1_46' 346/400
# processing 'split4_ir2_ov1_47' 347/400
# processing 'split4_ir2_ov1_48' 348/400
# processing 'split4_ir2_ov1_49' 349/400
# processing 'split4_ir2_ov1_50' 350/400
# processing 'split4_ir2_ov2_51' 351/400
# processing 'split4_ir2_ov2_52' 352/400
# processing 'split4_ir2_ov2_53' 353/400
# processing 'split4_ir2_ov2_54' 354/400
# processing 'split4_ir2_ov2_55' 355/400
# processing 'split4_ir2_ov2_56' 356/400
# processing 'split4_ir2_ov2_57' 357/400
# processing 'split4_ir2_ov2_58' 358/400
# processing 'split4_ir2_ov2_59' 359/400
# processing 'split4_ir2_ov2_60' 360/400
# processing 'split4_ir3_ov1_61' 361/400
# processing 'split4_ir3_ov1_62' 362/400
# processing 'split4_ir3_ov1_63' 363/400
# processing 'split4_ir3_ov1_64' 364/400
# processing 'split4_ir3_ov1_65' 365/400
# processing 'split4_ir3_ov1_66' 366/400
# processing 'split4_ir3_ov1_67' 367/400
# processing 'split4_ir3_ov1_68' 368/400
# processing 'split4_ir3_ov1_69' 369/400
# processing 'split4_ir3_ov1_70' 370/400
# processing 'split4_ir3_ov2_71' 371/400
# processing 'split4_ir3_ov2_72' 372/400
# processing 'split4_ir3_ov2_73' 373/400
# processing 'split4_ir3_ov2_74' 374/400
# processing 'split4_ir3_ov2_75' 375/400
# processing 'split4_ir3_ov2_76' 376/400
# processing 'split4_ir3_ov2_77' 377/400
# processing 'split4_ir3_ov2_78' 378/400
# processing 'split4_ir3_ov2_79' 379/400
# processing 'split4_ir3_ov2_80' 380/400
# processing 'split4_ir4_ov1_81' 381/400
# processing 'split4_ir4_ov1_82' 382/400
# processing 'split4_ir4_ov1_83' 383/400
# processing 'split4_ir4_ov1_84' 384/400
# processing 'split4_ir4_ov1_85' 385/400
# processing 'split4_ir4_ov1_86' 386/400
# processing 'split4_ir4_ov1_87' 387/400
# processing 'split4_ir4_ov1_88' 388/400
# processing 'split4_ir4_ov1_89' 389/400
# processing 'split4_ir4_ov1_90' 390/400
# processing 'split4_ir4_ov2_100' 391/400
# processing 'split4_ir4_ov2_91' 392/400
# processing 'split4_ir4_ov2_92' 393/400
# processing 'split4_ir4_ov2_93' 394/400
# processing 'split4_ir4_ov2_94' 395/400
# processing 'split4_ir4_ov2_95' 396/400
# processing 'split4_ir4_ov2_96' 397/400
# processing 'split4_ir4_ov2_97' 398/400
# processing 'split4_ir4_ov2_98' 399/400
# processing 'split4_ir4_ov2_99' 400/400
# (15798, 1536)
# Done!
# (1421, 1536)
# 1421

# %%
#print(features[100,:])
#for i in range(200):
#    plt.plot(features[i+20,:])
print(features.shape)
plt.plot(features[80])
# Out:
# (1421, 1536)

# %%
#no we reload from file and re-extract the three separate arrays containing features, labels, and filenames
imported_dataset = pd.read_csv('dataset.csv')

# %%
#we stored 7 features when the data structure was empty, so they eneded in culumns 0 to 6 (included)
#iloc[:,0:6] means : ==> all rows, 0:7 ==> columns 0 to 6 (7 is not included)
imported_features = imported_dataset.iloc[:,0:65536].to_numpy()#we stored 7 features when the data structure was empty, so they eneded in culumns 0 to 6 
imported_labels = np.zeros((imported_features.shape[0],3))
imported_labels[:,0] = imported_dataset['x'] #we keep this as a pandas data structure, it will be handy to trace back misclassified files (because it's indexed)
imported_labels[:,1] = imported_dataset['y']
imported_labels[:,2] = imported_dataset['z']
features = imported_features
target = imported_labels

# %%
sr = 22050
melFreSize = 128
melTimeSamples = 1024

def getSpectrum(s):
    y = s[0:2048] * scipy.signal.blackmanharris(2048)
    X_amp = np.abs(np.fft.rfft(y))
    X_db = 20 * np.log10(X_amp)
    #freqs = np.fft.rfftfreq(2048, 1/sr)#this is not used
    return X_db
# def get_combine_feature(signal):
#     output = []
#     for i in range(signal.shape[0] - 1):
#         for j in range(i + 1, signal.shape[0]):
#             #print(i,"*" ,j)
#             #Lag calculation
#             cross = scipy.signal.correlate(signal[i], signal[j], mode ='full')
#             output.append(np.argmax(cross)-len(cross)/2)
#             #RMS Diference
#             rmsDiff = np.mean(librosa.feature.rms(signal[i])) - np.mean(librosa.feature.rms(signal[j]))
#             output.append(rmsDiff)
#     return output

def get_combine_feature(signal):
    output = []
    for i in range(signal.shape[0] - 1):
        for j in range(i + 1, signal.shape[0]):
            cross = scipy.signal.correlate(signal[i], signal[j], mode ='full')
            output.append(np.argmax(cross)-len(cross)/2)

    lag = sklearn.preprocessing.normalize(np.array(output).reshape(1,-1))
    
    output = []
    for i in range(signal.shape[0] - 1):
          for j in range(i + 1, signal.shape[0]):
            rmsDiff = np.mean(librosa.feature.rms(signal[i])) - np.mean(librosa.feature.rms(signal[j]))
            output.append(rmsDiff)

    rms = sklearn.preprocessing.normalize(np.array(output).reshape(1,-1))
    
    output = []        
    for i in range(signal.shape[0] - 1):
          for j in range(i + 1, signal.shape[0]):
            #RMS from spectrum Diference
            rmsDiff = np.mean(librosa.feature.rms(getSpectrum(signal[i]))) - np.mean(librosa.feature.rms(getSpectrum(signal[j])))
            output.append(rmsDiff)

    rms_spec = sklearn.preprocessing.normalize(np.array(output).reshape(1,-1))

    output = lag.flatten().tolist()
    output.extend(rms.flatten().tolist())
    #output = rms.flatten().tolist()
    output.extend(rms_spec.flatten().tolist())
    return output

def extract_features_target(signal, location):
    output_time = get_combine_feature(signal)   
        #for i in range(signal.shape[0]):
    #    output.extend([np.mean(signal[i]), np.var(signal[i])])
    return output_time, np.array(location)
#     output = librosa.feature.melspectrogram(signal[0], n_mels=15)
#     output = output.flatten()
    #output_time = get_lag_feature(signal)
    
    
#     melSig = np.zeros((4, melFreSize*melTimeSamples))
#     for i in range(signal.shape[0]):
#         melSpec = librosa.feature.melspectrogram(signal[i], n_mels=melFreSize)
#         #print(signal[i].shape, ", ", signal[i,:].shape)
        
        
#         melSpec = lin_interp_2d(melSpec, (melFreSize, melTimeSamples))
#         #showMel(melSpec)
#         melSig[i,:] = melSpec.flatten()
#     #output_freq = get_lag_feature(melSig)
#     output_mel = melSig.flatten()
    
    
#     #for i in range(signal.shape[0]):
#     #    output.extend([np.mean(signal[i]), np.var(signal[i])])
#     #output_time.extend(output_freq)
#     return output_mel, np.array(location)

#creating an array of zeros of the proper size where we will store computed features and lables

filenames_meta = os.listdir('data/dcase_data/metadata_dev') #Development
features = np.zeros((len(full_metadata),18)) #we compute the melspectrogram which once flattened will produce 22144 values
target = np.zeros((len(full_metadata),3)) #we store the 2 target values

example = 0
for i in range(max_it):
    
    #Metadata
    metadata = pd.read_csv('data/dcase_data/metadata_dev/' + filenames_meta[i])  #Development
    filename = os.path.splitext(filenames_meta[i])[0]
    
    print("processing '" + filename + "' " + str(i + 1) + "/" + str(max_it))
    
    #Audio track
    signal, dummy = librosa.load('data/dcase_data/foa_dev/' + filename + '.wav', sr, mono=False)    
    
    for s in range(len(metadata)):
        if(metadata['sound_event_recording'][s] == 'phone' ):
            #print('processing',filenames[i])
            start_time = int(metadata['start_time'][s] * sr)
            end_time = int(metadata['end_time'][s] * sr)
            #print(str(end_time - start_time))
            subsignal = signal[:, start_time:end_time]
            #features[example,:], target[example,:] = extract_features_target(subsignal, metadata['x'][s],  metadata['y'][s], metadata['z'][s])
            features[example,:], target[example,:] = extract_features_target(subsignal, normalize(SphericalToCartesian(metadata['ele'][s],  metadata['azi'][s], metadata['dist'][s])))
            
            #Ipd.display(Ipd.Audio(subsignal, rate=sr))
            example += 1
print(features.shape)            
features = np.delete(features, np.arange(example,features.shape[0], 1, dtype=int), axis=0)
target = np.delete(target, np.arange(example,target.shape[0], 1, dtype=int), axis=0)
print('Done!')
print(features.shape)
print(example)

# %%
print(features.shape)
print(target.shape)
# Out:
# (1421, 12288)
# (1421, 3)

# %%
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA


#creating pipeline
#note that here we do not initialize the parameters we want to tune/change
#the parameters that we decide to initialize here will be fixed across the grid search
#we also need to keep track of the names (between the quotes)
#that we selected for the different components of the pipeline
#the names are needed when creating the grid of parameters

pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('dim_red', PCA(n_components = 128)),
        ('classifier', MLPRegressor(max_iter=1000, random_state = 1, activation='relu', alpha = 0.01))
        ])

#n_components = 10
#hidden_layer_sizes=(20,5), max_iter=10000, activation='relu'


#creating the repeated stratified k-folds
#this is not a must, we can do grid search with a simple k-fold
#cross validation by setting cv= to a number in the GridSearchCV constructor
rkf = RepeatedKFold(n_splits=5, n_repeats=10)


#defining the parameters range to explore
#the name of the parameters is preceeded by the name of the component
#in the pipeline followed by two underscore
#if you have trouble in identifying the correct, print all parameters and their
#names uwith the following commented line
#print(pipe.get_params().keys())
# grid_param = {
#     'dim_red__n_components': [16, 32, 64, 128],
#     #'classifier__hidden_layer_sizes': [(128, 128, 128), (81,27,9), (30,20,10), (500, 400, 300, 100, 50)],
#     'classifier__hidden_layer_sizes': [(256,128,64,32, 16, 8), (500, 400, 300, 100, 50)],
#     'classifier__activation': ['tanh', 'relu', 'logistic'],
#     'classifier__alpha': [0.01, 0.001],
# }

grid_param = {
    'dim_red__n_components': [256, 300, 400, 512],
    #'dim_red__n_components': [34, 55, 89,144,233],
    #'classifier__hidden_layer_sizes': [(10,9,8,7,6,5,4), (9,5,3), (13,8,5), (34,21)],#377
    'classifier__hidden_layer_sizes': [(100, 50), (50,25), (34,21), (20, 10), (18,6)],#377
    #'classifier__hidden_layer_sizes': [(128, 128, 128), (81,27,9), (30,20,10), (500, 400, 300, 100, 50)],377
    #'classifier__hidden_layer_sizes': [(377, 233,144,89,55,34,21,13,8,5), (233,144,89,55,34,21,13,8,5)],
    'classifier__activation': ['logistic', 'relu', 'tanh'],
    'classifier__alpha': [0.1, 0.001],
}

gd_sr = GridSearchCV(estimator=pipe,
                     param_grid=grid_param,
                     scoring='r2', #this can be changes to accuracy, f1_micro, etc. or to another classification metric
                     cv=5, # if you do not want to do repeated kfold, you can set cv=5 to test just on 5 different splits 
                     n_jobs=-1, #if equal to -1 will use as many CPU as available
                     verbose = 4) 

gd_sr.fit(features, target) #performing the search

print('best set of parameters', gd_sr.best_params_)
print('associated best score',gd_sr.best_score_)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:  7.2min finished
# best set of parameters {'classifier__activation': 'logistic', 'classifier__alpha': 0.1, 'classifier__hidden_layer_sizes': (50, 25), 'dim_red__n_components': 256}
# associated best score 0.5197625415229652

# %%
gd_sr.predict()
